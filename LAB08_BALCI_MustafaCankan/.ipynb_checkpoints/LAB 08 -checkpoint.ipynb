# %%
from Country import Country

# %%
def readCountries(file_name,list_country):
    file_country = open(file_name,'r')
    for line in file_country:
        l_split = line.split(',')
        country = l_split[0].strip()
        continent = l_split[1].strip()
        life_m = float(l_split[2])
        life_f = float(l_split[3])
        list_country.append(Country(country,continent,life_m,life_f))
        
def selectionSort(list_country):
    counter = 0
    while counter != len(list_country):
        min_val = counter
        for i in range(counter, len(list_country)):
            if list_country[min_val].getContinent() > list_country[i].getContinent() :
                min_val = i
            elif list_country[min_val].getContinent() == list_country[i].getContinent() and list_country[min_val].getCountry() > list_country[i].getCountry():
                min_val = i
        
        list_country[counter],list_country[min_val] = list_country[min_val],list_country[counter]
        
        counter += 1
        
        
def searchCountries(list_country,search_continent,counter,l):
    if counter == len(list_country):
        print("List of Countries in " + search_continent)
        for j in l:
            print(j)
    else:
        if list_country[counter].getContinent() == search_continent:
            l.append(list_country[counter])
        return searchCountries(list_country,search_continent,counter +1,l)
        
        
        
        
        
list_country = []
        
readCountries("country.txt",list_country)

enter_continent = input('Enter continent to search: ')

searchCountries(list_country,enter_continent,0,[])

enter_country_class = input('Enter country name,continet, life expectany for Men and life expectany for Women: ')


l = enter_country_class.split(",")
country = l[0].strip()
continent = l[1].strip()
life_m = float(l[2])
life_f = float(l[3])
list_country.append(Country(country,continent,life_m,life_f))
print("New Country added")

selectionSort(list_country)
print("")
print("Countries by Continent and Name:")
print(list_country)
# Out:
# Enter continent to search: Asia
# List of Countries in Asia
# Country:Jordan
# Continent: Asia
# Average Life Expectancy: 69.75
#
# Country:Afghanistan
# Continent: Asia
# Average Life Expectancy: 45.5
#
# Country:Turkey
# Continent: Asia
# Average Life Expectancy: 69.1
#
# Country:China
# Continent: Asia
# Average Life Expectancy: 69.95
#
# Country:Iran
# Continent: Asia
# Average Life Expectancy: 69.25
#
# Country:Iraq
# Continent: Asia
# Average Life Expectancy: 62.4
#
# Country:Japan
# Continent: Asia
# Average Life Expectancy: 79.9
#
# Enter country name,continet, life expectany for Men and life expectany for Women: Egypt, Africa, 45.7,42.5
# New Country added
#
# Countries by Continent and Name:
# [Country:Egypt
# Continent: Africa
# Life Expectancy for Males: 45.7
# Life Expectancy for Females: 42.5
# , Country:Nigeria
# Continent: Africa
# Life Expectancy for Males: 50.8
# Life Expectancy for Females: 54.0
# , Country:Bolivia
# Continent: America
# Life Expectancy for Males: 59.8
# Life Expectancy for Females: 63.2
# , Country:Brazil
# Continent: America
# Life Expectancy for Males: 63.4
# Life Expectancy for Females: 71.2
# , Country:Canada
# Continent: America
# Life Expectancy for Males: 76.1
# Life Expectancy for Females: 81.8
# , Country:United.States
# Continent: America
# Life Expectancy for Males: 73.4
# Life Expectancy for Females: 80.1
# , Country:Afghanistan
# Continent: Asia
# Life Expectancy for Males: 45.0
# Life Expectancy for Females: 46.0
# , Country:China
# Continent: Asia
# Life Expectancy for Males: 68.2
# Life Expectancy for Females: 71.7
# , Country:Iran
# Continent: Asia
# Life Expectancy for Males: 68.5
# Life Expectancy for Females: 70.0
# , Country:Iraq
# Continent: Asia
# Life Expectancy for Males: 60.9
# Life Expectancy for Females: 63.9
# , Country:Japan
# Continent: Asia
# Life Expectancy for Males: 76.9
# Life Expectancy for Females: 82.9
# , Country:Jordan
# Continent: Asia
# Life Expectancy for Males: 67.7
# Life Expectancy for Females: 71.8
# , Country:Turkey
# Continent: Asia
# Life Expectancy for Males: 66.5
# Life Expectancy for Females: 71.7
# , Country:Bulgaria
# Continent: Europe
# Life Expectancy for Males: 67.8
# Life Expectancy for Females: 74.9
# , Country:France
# Continent: Europe
# Life Expectancy for Males: 74.6
# Life Expectancy for Females: 82.9
# , Country:Germany
# Continent: Europe
# Life Expectancy for Males: 73.4
# Life Expectancy for Females: 79.9
# , Country:Greece
# Continent: Europe
# Life Expectancy for Males: 75.5
# Life Expectancy for Females: 80.6
# , Country:Hungary
# Continent: Europe
# Life Expectancy for Males: 64.5
# Life Expectancy for Females: 73.8
# , Country:Italy
# Continent: Europe
# Life Expectancy for Males: 75.1
# Life Expectancy for Females: 81.4
# , Country:Norway
# Continent: Europe
# Life Expectancy for Males: 74.8
# Life Expectancy for Females: 80.6
# , Country:Russia
# Continent: Europe
# Life Expectancy for Males: 58.0
# Life Expectancy for Females: 71.5
# , Country:United.Kingdom
# Continent: Europe
# Life Expectancy for Males: 74.5
# Life Expectancy for Females: 79.8
# ]
